# %%
pip install -U llama-index --upgrade --no-cache-dir --force-reinstall
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 0.8/1.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 1.3 MB/s eta 0:00:01
# ...

# %%
pip install llama-parse
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
current_directory = os.getcwd()
current_directory
# Out:
# 'c:\\Users\\ml_project\\cold-email-generator'

# %%
os.chdir("..")

# %%
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("API_KEY")

# Print the API key (or use it in your application)
print("API Key:", api_key)
# Out:
# API Key: llx-uWun9e05lJmbAQeEEYBvluDZ8NgE6sJkAgGfkUffuzarJFke

# %%
import nest_asyncio


nest_asyncio.apply()

from llama_parse import LlamaParse

parser = LlamaParse(
    api_key=api_key,  # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type="markdown",  # "markdown" and "text" are available
    verbose=True,
)

# sync
documents = parser.load_data("./test.pdf")

# # sync batch
# documents = parser.load_data(["./my_file1.pdf", "./my_file2.pdf"])

# # async
# documents = await parser.aload_data("./my_file.pdf")

# # async batch
# documents = await parser.aload_data(["./my_file1.pdf", "./my_file2.pdf"])
# Out:
# Started parsing the file under job_id 133bfa2f-e9ae-420d-afeb-3210dd52ef89
# .........

# %%
documents
# Out:
# [Document(id_='73a13428-ee6c-4db4-91ae-7a4c12e7d439', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Check for updates', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='472d1a68-6ef2-4a47-980e-9ae06e74c33f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Inlet pressure pon\n\n# Micro pin fin bundle\n\n# Flow in\n\n# Flow distributor\n\n# Exit pressure pont\n\n# Pin fins\n\n# Bottom wall (endwall)', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...

# %%
print(documents[8].text[:])
# Out:
# # Device Data
#
# |Device| |Q (mlmin)|fGaddis|fsparrow|fmoores|fKast|fGunther|fchilton|J Bergelin|Jskort|JHEDH|fExperiment|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |ISDS|30.29|3.924|0.07828|5.093|2.0544|2.793|0.7599|0.1136|0.02284|0.3674|0.035404|3.152|
# |ISDS|26.83|3.476|0.08835|5.633|2.1832|2.953|0.8577|0.1282|0.02578|0.3975|0.034892|3.849|
# |ISDS|24.12|3.125|0.09828|6.165|2.3032|3.107|0.954|0.1426|0.02868|0.426|0.03448|4.61|
# |ISDS|21.55|2.792|0.11|6.793|2.4372|3.286|1.068|0.1596|0.0321|0.4583|0.034084|5.691|
# |ISDS|20.07|2.6|0.1181|7.228|2.526|3.408|1.147|0.1714|0.03447|0.4801|0.03386|2298|
# |ISDS|18.15|2.351|0.1306|7.898|2.6568|3.594|1.268|0.1895|0.03812|0.5125|0.03358|7.069|
# |ISDS|16.75|2.171|0.1415|8.48|2.7656|3.753|1.374|2053|0.04129|0.5398|033388|7.953|
# |ISDS|14.5|1.878|0.1635|9.661|2.974|4.072|588|2373|0.04772|0.5931|0.033116|7.898|
# |ISDS|12.75|1.652|0.1859|10.86|3.1716|4.39|.805|2697|05425|6446|0.032968|10.44|
# ...

# %%
file_name = "test.md"
with open(file_name, 'w') as file:
    file.write(documents[8].text)

# %%
parser = LlamaParse(
    api_key=api_key,  # can also be set in your env as LLAMA_CLOUD_API_KEY
    result_type="markdown",  # "markdown" and "text" are available
    verbose=True,
)

# sync
documents = parser.load_data("./test.pdf")

# %%
tables = llama_parse.extract_tables(pdf_path)

# Print extracted table data
for i, table in enumerate(tables):
    print(f"Table {i + 1}:")
    for row in table:
        print(row)
    print("\n")
